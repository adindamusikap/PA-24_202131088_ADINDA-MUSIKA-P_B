# %% [markdown]
# # Adinda Musika Permata_202131088

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Membaca Gambar

# %%
gambar = cv2.imread('gambaruas.jpg')

# %% [markdown]
# # Konversi Gambar Ke Grayscale

# %%
abu_abu = cv2.cvtColor(gambar, cv2.COLOR_BGR2GRAY)

# %% [markdown]
# # Melakukan Operasi Deteksi Tepi pada Gambar

# %%
tanda_tepi = cv2.Canny(abu_abu, 30, 150)

# %% [markdown]
# # Mencari Kontur Pada Gambar

# %%
kontur, _ = cv2.findContours(tanda_tepi, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# %% [markdown]
# # Salinan Gambar Asli

# %%
gambar_asli = np.copy(gambar)

# %% [markdown]
# # Gambar Kontur pada Gambar Asli

# %%
cv2.drawContours(gambar_asli, kontur, -1, (0, 0, 255), 3)
# Out:
# array([[[126, 120, 121],
#         [126, 120, 121],
#         [125, 119, 120],
#         ...,
#         [161, 164, 162],
#         [161, 164, 162],
#         [161, 164, 162]],
#
#        [[126, 120, 121],
#         [126, 120, 121],
#         [125, 119, 120],
#         ...,
#         [161, 164, 162],
#         [161, 164, 162],
#         [161, 164, 162]],
#
#        [[126, 120, 121],
#         [126, 120, 121],
#         [125, 119, 120],
#         ...,
#         [162, 165, 163],
#         [162, 165, 163],
#         [162, 165, 163]],
#
#        ...,
#
#        [[ 65,  64,  66],
#         [ 65,  64,  66],
#         [ 65,  64,  66],
#         ...,
#         [140, 135, 136],
#         [140, 135, 136],
#         [140, 135, 136]],
#
#        [[ 65,  64,  66],
#         [ 65,  64,  66],
#         [ 65,  64,  66],
#         ...,
#         [138, 133, 134],
#         [138, 133, 134],
#         [138, 133, 134]],
#
#        [[ 64,  63,  65],
#         [ 64,  63,  65],
#         [ 64,  63,  65],
#         ...,
#         [137, 132, 133],
#         [137, 132, 133],
#         [137, 132, 133]]], dtype=uint8)

# %% [markdown]
# # Menampilkan Gambar dalam Subplot

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
# Menampilkan gambar asli pada subplot pertama
ax[0].imshow(cv2.cvtColor(gambar, cv2.COLOR_BGR2RGB))
ax[0].set_title('Gambar Asli')

# Menampilkan gambar dengan kontur pada subplot kedua
ax[1].imshow(cv2.cvtColor(gambar_asli, cv2.COLOR_BGR2RGB))
ax[1].set_title('Gambar Contour')
# Out:
# Text(0.5, 1.0, 'Gambar\xa0Contour')
